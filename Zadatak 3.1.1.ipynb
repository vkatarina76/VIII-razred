# %% [markdown]
# Користећи Џупајтер радну свеску израчунај следеће изразе

# %%
(514 + 10) * 15
# Out:
# 7860

# %%
4**(15**3)
# Out:
# ...

# %%
(874 + 437) * (915 - 364)
# Out:
# 722361

# %%
4*79 + 8*99 + 4*59 + 2*79 + 6*59
# Out:
# 1856

# %%
1/2+1/5+1/9+1/4
# Out:
# 1.0611111111111111
